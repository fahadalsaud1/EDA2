# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadalsaud1/EDA2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction
# In my Exploratory data analyis project, I looked into the English Premier Leageu (the best soccer league in the world). In particular, I looked for the historical results of each and which teams have been the most successful in the past. As well, using statistics, I also analyzed which individual stats most strongly correlate with wins.
#
# Link to dataset origin: https://www.kaggle.com/zaeemnalla/premier-league

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sn

# %%
results = pd.read_csv('results.csv')
stats = pd.read_csv('stats.csv')

# %% [markdown]
# # Data Wrangling
# Although my data wrangling wasn't too difficult, I had to remove certain columns that were missing data points in order to have a cleaner and more useful dataset.

# %%
stats.drop(["dispossessed", "big_chance_missed", "backward_pass", "backward_pass", "total_through_ball"], axis=1)
# Out:
#                      team  wins  losses  ...  total_high_claim  punches     season
# 0       Manchester United  28.0     5.0  ...              37.0     25.0  2006-2007
# 1                 Chelsea  24.0     3.0  ...              74.0     22.0  2006-2007
# 2               Liverpool  20.0    10.0  ...              51.0     27.0  2006-2007
# 3                 Arsenal  19.0     8.0  ...              88.0     27.0  2006-2007
# 4       Tottenham Hotspur  17.0    12.0  ...              51.0     24.0  2006-2007
# ..                    ...   ...     ...  ...               ...      ...        ...
# 235     Huddersfield Town   9.0    19.0  ...              31.0     24.0  2017-2018
# 236          Swansea City   8.0    21.0  ...              44.0     15.0  2017-2018
# 237           Southampton   7.0    16.0  ...              29.0     13.0  2017-2018
# 238            Stoke City   7.0    19.0  ...              27.0     14.0  2017-2018
# ...

# %%
# Finding the use of home advantage

hw = results.query("home_goals > away_goals")
home_wins = (hw.shape[0])
aw = results.query("away_goals > home_goals")
away_wins = (aw.shape[0])
dr = results.query("away_goals == home_goals")
draw = (dr.shape[0])
value = [home_wins, away_wins, draw]
lab= 'Home Wins','Away Wins','Draws'
plt.pie(value, labels = lab, autopct='%1.1f%%')
plt.title('Home Advantage')
plt.axis('equal')
plt.show()

# %%
# This is the amount of goals per year
# My hypothesis on why this is happening is because overtime, teams tried score more goals in order to attract more fans. 
stats["Goals"] = stats['goals']
stats.groupby('season')["Goals"].sum().plot()
plt.title('Goals per Season')
plt.ylabel('Goals')
# Out:
# Text(0, 0.5, 'Goals')

# %%
stats.groupby('team')["wins"].agg(['mean']).sort_values(ascending=False, by='mean').plot.bar(figsize = (10,5))
plt.title('Average Wins per Season')
plt.ylabel('Wins')
plt.xlabel('Teams')
lulu = stats.groupby('team')['wins'].mean()
# This graph shows the best teams, on average, from 2006-2018

# %%
yot = results[results.home_goals > results.away_goals]
hel = yot['home_team'].value_counts()
awt = results[results.away_goals > results.home_goals]
sec = awt['away_team'].value_counts()
frt = (hel/(sec + hel)).sort_values(ascending=False)
frt.plot.bar(figsize = (10,5))
plt.title('Percent of Wins coming at home')
plt.ylabel('% of wins at home')
plt.xlabel('Teams')
# This graph was used to measure the home field advantage of each team, and which teams relied on a home crowd for their victories.
# Out:
# Text(0.5, 0, 'Teams')

# %%
topp = stats.loc[stats.groupby('season')['wins'].idxmax()]
secondw = topp.team.value_counts() 

seasonsinprem = stats['team'].value_counts()
ily = hel/seasonsinprem
ily
msy = sec/seasonsinprem

ily.corr(secondw)
# I tried to find a correlation between home wins and titles won vs away wins and titles won. 
# Since the home wins correlation was greater than the away wins correlation, teams that won the title typically win much more games at home than away.
# Out:
# 0.9467531164008038

# %%
msy.corr(secondw)
# Out:
# 0.8317883872610063

# %%
frt.corr(lulu)
# this correlation measured average wins and percentage of wins at home.
# This portrays that worse teams really on home field rather than the better teams.
# Out:
# -0.5029142730791075

# %%
gdb = stats.wins
gdb
yor = stats.goals
yor
shap = stats.touches
n_1 = yor.corr(gdb)
n_2 = shap.corr(gdb)
m_1 = stats.total_long_balls
n_3 = m_1.corr(gdb)
m_2 = stats.total_cross
n_4 = m_2.corr(gdb)
print(n_1, n_2, n_3,n_4)
# These correlations measure the effectiveness of certain actions and wins.
# From left to right, the correlations were goals, touches, long balls, and crosses
# Out:
# 0.8992362728131303 0.7046451802179229 -0.22813466009723063 0.2081962173298688

# %%
missing = stats.plot.scatter(x='wins',y='goals')
plt.title('Correlation between Goals and Wins, corr = 0.899')
# Out:
# Text(0.5, 1.0, 'Correlation between Goals and Wins, corr = 0.899')

# %%
miss_2 = stats.plot.scatter(x='wins',y='touches')
plt.title('Correlation between Touches and Wins, corr = 0.705')
# Out:
# Text(0.5, 1.0, 'Correlation between Touches and Wins, corr = 0.705')

# %%
miss_3 = stats.plot.scatter(x='wins',y='total_long_balls')
plt.title('Correlation between Long Balls and Wins, corr = -0.228')
# Out:
# Text(0.5, 1.0, 'Correlation between Long Balls and Wins, corr = -0.228')

# %%
miss_3 = stats.plot.scatter(x='wins',y='total_cross')
plt.title('Correlation between Crosses and Wins, corr = 0.208')
# Out:
# Text(0.5, 1.0, 'Correlation between Crosses and Wins, corr = 0.208')

# %%
twplu = (stats.groupby(['team'])['wins'].sum().sort_values(ascending=False).reset_index()['team'])
wpspv = (stats.pivot_table(index='team',values='wins',columns='season').fillna(0).reindex(twplu))

plt.figure(figsize=(5, 10))
sn.heatmap(wpspv, cmap='YlGnBu')
# This is a heatmap measuring each teams win per season.

# %% [markdown]
# ### Final Conclusion
# In my Exploratory data analyis project, I looked into the English Premier Leageu (the best soccer league in the world). In particular, I looked for the historical results of each and which teams have been the most successful in the past. As well, using statistics, I also analyzed which individual stats most strongly correlate with wins.
#
# After my analysis, I came to a couple of conclusions. Primarily, I learned about the teams that have been the most successful from 2006-2018 (Manchester United, Chelsea, Manchester City. Also, through further analysis I found out that there are certain teams that rely on home field advantage more than others. Furthermore, teams with higher average wins per season are negatively correlated with % of wins coming at home. This means that, on average, better teams rely less on home field advantage than worse teams who need the extra boost in order to be victorious.
#
# I also learned that there are certain variables that directly correlate with wins. Both touches of the ball and goals are strongly correlated with wins. This analysis should inspire teams to attack more (score more goals) and keep more possesion of the ball (amount of touches) if they want to win games. Also, there is a weak negative correlation between long balls and wins. Thus, although not a strong correlation, teams should try to limit playing long balls but rather rely on short passed. As well, there was a weak positive correlation between crosses and wins. Thus, although not a strong correlation, teams should try to attempt more crossers per game.
